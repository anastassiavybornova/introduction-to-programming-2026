# %% [markdown]
# # Introduction to Programming - Exercise 05
#
# Topics covered:
# * lists, tuples, and sets
# * for and while loops
# * function definitions
# * conditional statements
# * `range()`
#
# Tasks:
# * Task 1: At the supermarket
# * Task 2: Defining sequences from 1 to 10
# * Task 3: Counting letters
# * Task 4: At the ice cream shop
# * Task 5: Summing up numbers
# * Task 6: Finding divisors
# * Task 7: Summing up numbers, but we stop at 253
# * Task 8: Find the bug
# * Task 9: Coding on paper

# %% [markdown]
# ***
# ## Task 1: At the supermarket (list methods)
#
# ```python
# shopping_list = ["onions", "milk", "bread", "butter", "rice", "vinegar", "oil", "pineapple", "onions", "salt", "chicken", "parsley", "mint", "sugar", "onions"]
# snacks = ["chocolate", "ice cream", "chips"]
# ```
#
# Above, we have defined a shopping list, and a snack list. Use list methods (`.index()`, `.append()`, `.remove()`, `.sort()`, `.count()`) and/or assignment operators (`+`,`+=`) to:
# * add `"oranges"` to the shopping list
# * add the `snacks` list to the shopping list (try to use `+`, `+=`, and `.append()`! What is the difference?)
# * find out at which list position is the `"chicken"`
# * remove `"butter"` from the shopping list (turns out we already have that at home)
# * count how many times does `"onions"` appear on the list
# * sort the shopping list alphabetically, and print it out
# * make sure that every item appears only once by converting the list to a set, and saving it into the variable `shopping_set`.
# * how many *unique* items are in our shopping set now?

# %%
# run this cell to define the 2 list variables
# (also run this cell again if you mess up the +/+=/.append() task :)
shopping_list = ["onions", "milk", "bread", "butter", "rice", "vinegar", "oil", "pineapple", "onions", "salt", "chicken", "parsley", "mint", "sugar", "onions"]
snacks = ["chocolate", "ice cream", "chips"]

# %%
# YOUR CODE HERE

# %% [markdown]
# ***
#
# ## Task 2: Defining sequences from 1 to 10
#
# **(2a)** Define `my_tuple`, a tuple with all numbers from 1 to 10, in ascending order, by hand.
#
# **(2b)** Define the same tuple, but using `range()`instead.
#
# **(2c)** Define `my_list`, a *list* with the same numbers, using a `for` loop and the list method `.append()`.
#
# > **Hint 1:** Create an empty list before the for loop.
#
# > **Hint 2:** Use `range()` to create an iterable object for the for loop.
#
# **(2d)** Define the same list with the same numbers, but using a `while` loop.
#
# > **Hint 1:** Before the while-loop, define an empty list.
#
# > **Hint 2:** Also before the while-loop, define `i=1` (this will be the first element added to our empty list); and increase i by 1 in each loop iteration.

# %%
# YOUR CODE HERE

# %% [markdown]
# ***
# ## Task 3: Counting letters
#
# **(3a)** Write a for-loop that iterates over the string `"THE CAPITAL OF MADAGASCAR IS ANTANANARIVO"` and counts how many times the capital letter `A` appears in it. After the for-loop, print out the count. **Hint:** define the count before the for loop, and set it to 0.
#
# **(3b)** Use your solution (the for-loop) from (3a) to define the function `count_A()`:
# * `count_A()` takes a string as an input;
# * uses a `for` loop to count how many times the capital letter `A` appears in the input string;
# * and returns the count value.
#
# Test your function `count_A()` on the string `"THE CAPITAL OF MADAGASCAR IS ANTANANARIVO"` by `assert`ing that it returns the expected number of letters.
#
# **(3c)** Use your solution from (3b) to define the function `count_Aa()`, which counts *both* capitalized and small letters (`A` and `a`). Test your modified function on the string `"A change is as good as a rest"` by asserting that it returns the expected number of letters.

# %%
# YOUR CODE HERE

# %% [markdown]
# ***
#
# ## Task 4: At the ice cream shop
#
# You are the owner of an ice cream shop. Your employee who sells the ice cream is a programming student! They decided to write down all ice cream orders of the day in Python. Find out:
#
# **(4a)** How many ice cream combinations have been sold today?
#
# **(4b)** How many **unique** ice cream combinations have been sold today?
#
# **(4c)** How many unique ice cream **flavors** (vanilla, banana, cookie, ...) have been sold? There are many ways to find this out.
#
# > **Hint**: You could, for example, use a nested for-loop (one "outer" for loop that iterates over all ice cream combinations; and an "inner" for loop one that iterates over the ice cream flavors).
#
# ***
#
# > **Note**: the orders are saved as tuples - and for the sake of this exercise, we assume that for ice cream uniqueness, the order matters: `('yoghurt', 'mint')` is **not** the same as `('mint', 'yoghurt')`
#
# ***
#
# ```python
# icecream_sold = [
#     ('yoghurt', 'mint'), ('cookie', 'cookie'), ('caramel', 'yoghurt'), ('yoghurt', 'straciatella'), ('caramel', 'straciatella'),
#     ('vanilla', 'yoghurt'), ('hazelnut', 'banana'), ('straciatella', 'straciatella'), ('cookie', 'cookie'), ('cookie', 'caramel'),
#     ('banana', 'straciatella'), ('cheesecake', 'cookie'), ('chocolate', 'chocolate'), ('mint', 'hazelnut'), ('hazelnut', 'cheesecake'),
#     ('caramel', 'vanilla'), ('yoghurt', 'mint'), ('cheesecake', 'vanilla'), ('chocolate', 'cookie'), ('mint', 'strawberry'), ('cookie', 'strawberry'),
#     ('hazelnut', 'vanilla'), ('yoghurt', 'strawberry'), ('strawberry', 'chocolate'), ('cheesecake', 'cookie'), ('straciatella', 'vanilla'),
#     ('caramel', 'banana'), ('mint', 'straciatella'), ('caramel', 'strawberry'), ('cookie', 'strawberry'), ('caramel', 'yoghurt'),
#     ('strawberry', 'mint'), ('mint', 'hazelnut'), ('banana', 'hazelnut'), ('straciatella', 'banana'), ('mint', 'straciatella'),
#     ('cheesecake', 'chocolate'), ('mint', 'yoghurt'), ('cookie', 'banana'), ('cheesecake', 'mint'), ('banana', 'straciatella'),
#     ('mint', 'straciatella'), ('straciatella', 'straciatella'), ('cookie', 'mint'), ('cookie', 'straciatella'), ('banana', 'caramel'),
#     ('mint', 'cheesecake'), ('chocolate', 'banana'), ('cheesecake', 'vanilla'), ('vanilla', 'yoghurt'), ('hazelnut', 'yoghurt'),
#     ('hazelnut', 'cookie'), ('strawberry', 'cookie'), ('yoghurt', 'cheesecake'), ('cheesecake', 'banana'), ('vanilla', 'hazelnut'),
#     ('cookie', 'strawberry'), ('mint', 'straciatella'), ('cheesecake', 'vanilla'), ('cookie', 'strawberry'), ('cookie', 'strawberry')
# ]
# ```

# %%
# RUN THIS CELL TO DEFINE THE VARIABLE icecream_sold
icecream_sold = [
    ('yoghurt', 'mint'), ('cookie', 'cookie'), ('caramel', 'yoghurt'), ('yoghurt', 'straciatella'), ('caramel', 'straciatella'),
    ('vanilla', 'yoghurt'), ('hazelnut', 'banana'), ('straciatella', 'straciatella'), ('cookie', 'cookie'), ('cookie', 'caramel'),
    ('banana', 'straciatella'), ('cheesecake', 'cookie'), ('chocolate', 'chocolate'), ('mint', 'hazelnut'), ('hazelnut', 'cheesecake'),
    ('caramel', 'vanilla'), ('yoghurt', 'mint'), ('cheesecake', 'vanilla'), ('chocolate', 'cookie'), ('mint', 'strawberry'), ('cookie', 'strawberry'),
    ('hazelnut', 'vanilla'), ('yoghurt', 'strawberry'), ('strawberry', 'chocolate'), ('cheesecake', 'cookie'), ('straciatella', 'vanilla'),
    ('caramel', 'banana'), ('mint', 'straciatella'), ('caramel', 'strawberry'), ('cookie', 'strawberry'), ('caramel', 'yoghurt'),
    ('strawberry', 'mint'), ('mint', 'hazelnut'), ('banana', 'hazelnut'), ('straciatella', 'banana'), ('mint', 'straciatella'),
    ('cheesecake', 'chocolate'), ('mint', 'yoghurt'), ('cookie', 'banana'), ('cheesecake', 'mint'), ('banana', 'straciatella'),
    ('mint', 'straciatella'), ('straciatella', 'straciatella'), ('cookie', 'mint'), ('cookie', 'straciatella'), ('banana', 'caramel'),
    ('mint', 'cheesecake'), ('chocolate', 'banana'), ('cheesecake', 'vanilla'), ('vanilla', 'yoghurt'), ('hazelnut', 'yoghurt'),
    ('hazelnut', 'cookie'), ('strawberry', 'cookie'), ('yoghurt', 'cheesecake'), ('cheesecake', 'banana'), ('vanilla', 'hazelnut'), 
    ('cookie', 'strawberry'), ('mint', 'straciatella'), ('cheesecake', 'vanilla'), ('cookie', 'strawberry'), ('cookie', 'strawberry')
]

# %%
# YOUR CODE HERE

# %% [markdown]
# ***
# ## Task 5: Summing up numbers
#
# **(5a)** Use a `for` loop and the variable `my_sum` (initally set to 0) to calculate the sum of all numbers from 0 to 500.
#
# **(5b)** Use a `for` loop and the variable `my_sum` (initally set to 0) to calculate the sum of all **even** numbers from 0 to 500.
#
# **(5c)** Use a `for` loop and the variable `my_sum` (initally set to 0) to calculate the sum of all **divisible by 100** numbers from 0 to 500.
#
# > **Hint:** For all three `for`-loops, use `range()` to create the iterable object
#
# > **Hint:** Use the modulo operator `%` for (5b) and (5c)

# %%
# YOUR CODE HERE

# %% [markdown]
# ***
#
# ## Task 6: Finding divisors
#
# Use the `%` operator and a `for` loop to find out by which numbers from 2 to 30 is `462231` divisible? Save them into a list and print out the list.

# %%
# YOUR CODE HERE

# %% [markdown]
# ***
#
# ## Task 7: Summing up numbers, but we stop at 253
#
# Use a `for` loop **or** a `while` loop to find out how many integers (0 + 1 + 2 + 3 ... + n) you need to sum up to obtain 253. (There are many different ways to do this! If you find just 1, that's enough :)
#
# **Hints** Think about how and when to break out of the loop; think about how to make sure that at each loop iteration, we increase by 1 the number that we are adding to the sum.
#
# > We can (but we don't have to...) write this task as an equation, that we want to solve for `n`:
#
# $\sum_{i=0}^{n}{i}=253$

# %%
# YOUR CODE HERE

# %% [markdown]
# ***
#
# ## Task 8: Finding the bug
#
# In the code below, somebody tried to remove all 2's from a list by looping through the list *indeces*, and removing the list *element* if its value is equal to 2.
# * Why does this not work? What is the hidden danger in this code?
# * Correct the code so that it removes all `2`s from the list! (there are several ways to do this)
#
# ```python
# my_list = [2, 1, 2, 3, 4, 5]
# for i in range(len(my_list)):
#      if my_list[i] == 2:
#         my_list.remove(my_list[i])
# print(my_list)
# ```

# %%
# Find the bug in the code below!
my_list = [2, 1, 2, 3, 4, 5]
for i in range(len(my_list)):
    if my_list[i] == 2:
        my_list.remove(my_list[i])
print(my_list)

# %%
# YOUR CODE HERE

# %% [markdown]
# ***
#
# ## Task 9: Coding on paper
#
# This is an exam question from the 2022's **PEN AND PAPER** exam of a similar course at ITU. Please try to solve this with "pen and paper"! Write down your answers. Then, check (by implementing the code in Python) whether your answers were correct.
#
# ```python
# i=0
# while i<=9:
#     print("*"*i)
#     i = i+1
# ```
# **Q1** How many times does the above while loop execute exactly?
#
# **Q2** What does the code print out? In particular, what exactly is printed in the last line?
#
# **Q3**  Write an implementation for the same functionality by replacing the while loop with a for loop.

# %% [markdown]
# YOUR ANSWERS HERE (IN WRITTEN TEXT)

# %%
# YOUR CODE HERE
